# %% [markdown]
# We will be extraction data for vegetation  using nasa modis dataset: name of the dataset "MOD13Q1.061 "
# will be using the google earth engine for the api call to extract the data

# %%
import ee

# %% [markdown]
# using geemap for the visualizing data

# %% [markdown]
# FYI if youre using google earth engine for the first time you do nee to register your project for commericail or non comeercial licene; this project is registed for non commerecoal usecase

# %%
import geemap


# Initialize the Earth Engine API
try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=-lS9GHL9xKkL9nprYKP9uW0WZAg6RBqFfcy1AXq8eNI&tc=iPGOnz-sKMJSP6PhCllD5k-zX8KRabJYIIR89NdEhBQ&cc=tz4u75jM6Na7xT8tOZklfylcTok5NbkS0KLBWYwdLuQ>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=-lS9GHL9xKkL9nprYKP9uW0WZAg6RBqFfcy1AXq8eNI&tc=iPGOnz-sKMJSP6PhCllD5k-zX8KRabJYIIR89NdEhBQ&cc=tz4u75jM6Na7xT8tOZklfylcTok5NbkS0KLBWYwdLuQ</a></p>
# ...

# %%
Modis_Collection = ee.ImageCollection('MODIS/061/MOD13Q1')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Intailizing boundary for cariboo and visualizing that boundary

# %%
cariboo = ee.Geometry.Rectangle([-124.5, 50.5, -120.0, 53.5])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
m = geemap.Map(center=[52.5, -122.5], zoom=6)
m.addLayer(cariboo, {'color': 'red'}, 'Cariboo Boundary')
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 m = geemap.Map(center=[52.5, -122.5], zoom=6)
#       2 m.addLayer(cariboo, {'color': 'red'}, 'Cariboo Boundary')
#       3 m
#
# NameError: name 'geemap' is not defined

# %% [markdown]
# we will mainly focus on year 2001-2024 for gathering data at the moment

# %%
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[52.5, -122.5], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright'…
